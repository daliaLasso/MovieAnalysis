# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
column_names = df.columns
column_names
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
unique_genres = df['genre'].unique()
unique_genres
# Out:
# array(['Drama', 'Crime,Drama', 'Action,Crime,Drama',
#        'Biography,Drama,History', 'Action,Adventure,Drama',
#        'Adventure,Western', 'Drama,Romance', 'Action,Adventure,Sci-Fi',
#        'Action,Adventure,Fantasy', 'Action,Sci-Fi',
#        'Biography,Crime,Drama', 'Crime,Drama,Mystery', 'Action,Drama',
#        'Drama,Family,Fantasy', 'Crime,Drama,Thriller', 'Drama,War',
#        'Adventure,Drama,Sci-Fi', 'Comedy,Drama,Romance',
#        'Crime,Drama,Fantasy', 'Adventure,Comedy,Sci-Fi',
#        'Animation,Adventure,Family', 'Biography,Drama,Music',
#        'Horror,Mystery,Thriller', 'Drama,Thriller',
#        'Animation,Adventure,Drama', 'Drama,Mystery,Sci-Fi', 'Drama,Music',
#        'Drama,Romance,War', 'Animation,Drama,War', 'Action,Drama,Mystery',
#        'Biography,Comedy,Drama', 'Western', 'Mystery,Thriller',
#        'Horror,Sci-Fi', 'Drama,Mystery,War', 'Drama,Western',
#        'Action,Adventure', 'Drama,Mystery,Thriller', 'Drama,Film-Noir',
# ...

# %%
print(df.dtypes)
# Out:
# rank             int64
# name            object
# year             int64
# rating         float64
# genre           object
# certificate     object
# run_time        object
# tagline         object
# budget          object
# box_office      object
# casts           object
# directors       object
# writers         object
# dtype: object

# %%
# extract hours and minutes of run_time
df[['Hours', 'Minutes']] = df['run_time'].str.extract(r'(?:(\d+)h)? ?(?:(\d+)m)?')

# Replace NaN with 0 and convert to integers
df['Hours'] = df['Hours'].fillna(0).astype(int)
df['Minutes'] = df['Minutes'].fillna(0).astype(int)

# compute total minutes
df['TotalMinutes'] = df['Hours'] * 60 + df['Minutes']

# compute the average 
average_run_time = df['TotalMinutes'].mean()

print(f"Average time in minutes: {average_run_time}")
# Out:
# Average time in minutes: 128.536
